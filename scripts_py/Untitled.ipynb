# %%
a = {'5': 3,
    '3': 5}

# %%
b = set(a.keys())
b -= set(['3'])

# %%
import numpy as np

# %%
x = np.random.random((1000, 5))

# %%
def test():
    return 1, 3

# %%
list(test())
# Out:
# [1, 3]

# %%
np.percentile(x, 50., axis=-1)
# Out:
# array([0.80725951, 0.57776401, 0.40179527, 0.55604433, 0.68591887,
#        0.35300362, 0.49975904, 0.75608201, 0.60578511, 0.59957722,
#        0.16809228, 0.44164416, 0.35693715, 0.61053747, 0.34986504,
#        0.43579929, 0.5743774 , 0.61809187, 0.79352926, 0.87619097,
#        0.23031032, 0.60866439, 0.18695069, 0.4039467 , 0.48190926,
#        0.48767796, 0.55184835, 0.40795955, 0.90217975, 0.70067397,
#        0.48368266, 0.51956496, 0.8399188 , 0.58081271, 0.55894054,
#        0.09933748, 0.59994345, 0.33384308, 0.36859793, 0.38174964,
#        0.61576744, 0.72855181, 0.36245939, 0.4130476 , 0.61128924,
#        0.80391435, 0.47260222, 0.64334987, 0.1711709 , 0.21575157,
#        0.3925504 , 0.11300795, 0.51395188, 0.31242985, 0.33858289,
#        0.60577967, 0.92828129, 0.82764084, 0.92751631, 0.51134393,
#        0.76447425, 0.24553958, 0.56695768, 0.42793888, 0.29680466,
#        0.15083332, 0.60664872, 0.35588708, 0.84570974, 0.28404714,
# ...
