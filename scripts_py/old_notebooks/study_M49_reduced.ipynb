# %%
import numpy as np, matplotlib.pyplot as plt, matplotlib as mpl, pcmdpy as ppy
from astropy.io import fits

# %matplotlib inline
# Out:
# GPU acceleration not available, sorry
# No module named 'pycuda'

# %%
mpl.rcParams['image.origin'] = 'lower'

# %%
plt.style.use('seaborn-poster')

# %%
data_f475w = fits.open('../data/hst_9401_01_acs_wfc_f475w_drz.fits')

# %%
data_f850lp = fits.open('../data/hst_9401_01_acs_wfc_f850lp_drz.fits')

# %%
data_both = fits.open('../data/hst_9401_01_acs_wfc_f850lp_f475w_sci.fits')

# %% [markdown]
# # F475W

# %%
data_f475w
# Out:
# [<astropy.io.fits.hdu.image.PrimaryHDU object at 0x11146d588>, <astropy.io.fits.hdu.image.ImageHDU object at 0x1114f3b38>, <astropy.io.fits.hdu.image.ImageHDU object at 0x1114fdef0>, <astropy.io.fits.hdu.image.ImageHDU object at 0x111500f98>, <astropy.io.fits.hdu.table.BinTableHDU object at 0x111539c88>, <astropy.io.fits.hdu.image.ImageHDU object at 0x111542f98>]

# %%
for hdu in data_f475w:
    print(hdu.name)
# Out:
# PRIMARY
# SCI
# WHT
# CTX
# HDRTAB
# EXP

# %% [markdown]
# ## PRIMARY

# %%
hdu0 = data_f475w[0]

# %%
hdu0.data

# %%
hdu0.header
# Out:
# SIMPLE  =                    T / Fits standard
# BITPIX  =                   16 / Bits per pixel
# NAXIS   =                    0 / Number of axes
# EXTEND  =                    T / File may contain extensions
# ORIGIN  = 'NOAO-IRAF FITS Image Kernel July 2003' / FITS file originator
# DATE    = '2017-08-12         ' / Date FITS file was generated
# IRAF-TLM= '2017-08-13T02:01:13' / Time of last modification
# COMMENT   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
#
# TELESCOP= 'HST'                / telescope used to acquire data
# INSTRUME= 'ACS   '             / identifier for instrument used to acquire data
#
#               / DATA DESCRIPTION KEYWORDS
#
# IMAGETYP= 'EXT               ' / type of exposure identifier
# PRIMESI = 'ACS   '             / instrument designated as prime
#
#               / TARGET INFORMATION
#
# ...

# %% [markdown]
# ## SCI

# %%
hdu1 = data_f475w[1]

# %%
hdu1.header
# Out:
# XTENSION= 'IMAGE   '           / Image extension
# BITPIX  =                  -32 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                 5611
# NAXIS2  =                 5598
# PCOUNT  =                    0 / number of parameters
# GCOUNT  =                    1 / number of groups
# INHERIT =                    T / inherit the primary header
# EXTNAME = 'SCI     '           / extension name
# EXTVER  =                    1
# BUNIT   = 'ELECTRONS/S'        / Units of science product
#
# CD1_1   = -1.3888888888888E-05
# CD1_2   = 4.87124858980755E-35
# CD2_1   =                  0.0
# CD2_2   = 1.38888888888896E-05
# CRVAL1  =    187.4393357296858
# CRVAL2  =    8.002988775314055
# CRPIX1  =     2805.99999999982
# CRPIX2  =    2799.499999999821
# CTYPE1  = 'RA---TAN'
# CTYPE2  = 'DEC--TAN'
# ORIENTAT=                  0.0
# VAFACTOR=                  1.0
#               / WFC CCD CHIP IDENTIFICATION
#
# ...

# %% [markdown]
# ## WEIGHT

# %%
hdu2 = data_f475w[2]

# %%
hdu2.header
# Out:
# XTENSION= 'IMAGE   '           / Image extension
# BITPIX  =                  -32 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                 5611
# NAXIS2  =                 5598
# PCOUNT  =                    0 / number of parameters
# GCOUNT  =                    1 / number of groups
# INHERIT =                    T / inherit the primary header
# EXTNAME = 'WHT     '           / extension name
# EXTVER  =                    1
#
# CD1_1   = -1.3888888888888E-05
# CD1_2   = 4.87124858980755E-35
# CD2_1   =                  0.0
# CD2_2   = 1.38888888888896E-05
# CRVAL1  =    187.4393357296858
# CRVAL2  =    8.002988775314055
# CRPIX1  =     2805.99999999982
# CRPIX2  =    2799.499999999821
# CTYPE1  = 'RA---TAN'
# CTYPE2  = 'DEC--TAN'
# ORIENTAT=                  0.0
# VAFACTOR=                  1.0
#               / World Coordinate System and Related Parameters
#
# ...

# %%
plt.imshow(data_f475w[2].data, norm=mpl.colors.Normalize(vmax=700))
plt.colorbar()

# %% [markdown]
# ## CONTEXT

# %%
hdu3 = data_f475w[3]
hdu3.header
# Out:
# XTENSION= 'IMAGE   '           / Image extension
# BITPIX  =                   32 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                 5611
# NAXIS2  =                 5598
# PCOUNT  =                    0 / number of parameters
# GCOUNT  =                    1 / number of groups
# INHERIT =                    T / inherit the primary header
# EXTNAME = 'CTX     '           / extension name
# EXTVER  =                    1
#
# CD1_1   = -1.3888888888888E-05
# CD1_2   = 4.87124858980755E-35
# CD2_1   =                  0.0
# CD2_2   = 1.38888888888896E-05
# CRVAL1  =    187.4393357296858
# CRVAL2  =    8.002988775314055
# CRPIX1  =     2805.99999999982
# CRPIX2  =    2799.499999999821
# CTYPE1  = 'RA---TAN'
# CTYPE2  = 'DEC--TAN'
# ORIENTAT=                  0.0
# VAFACTOR=                  1.0
#               / World Coordinate System and Related Parameters
#
# ...

# %%
np.unique(hdu3.data)
# Out:
# array([ 0,  1,  2,  4,  5,  8, 10], dtype=int32)

# %%
plt.hist(hdu3.data.flatten(), bins=30)
# Out:
# (array([1.5099675e+07, 0.0000000e+00, 0.0000000e+00, 1.2142000e+04,
#         0.0000000e+00, 0.0000000e+00, 1.0236000e+04, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         1.2794000e+04, 0.0000000e+00, 0.0000000e+00, 8.3229580e+06,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         1.0950000e+04, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         0.0000000e+00, 7.9416230e+06]),
#  array([ 0.        ,  0.33333333,  0.66666667,  1.        ,  1.33333333,
#          1.66666667,  2.        ,  2.33333333,  2.66666667,  3.        ,
#          3.33333333,  3.66666667,  4.        ,  4.33333333,  4.66666667,
#          5.        ,  5.33333333,  5.66666667,  6.        ,  6.33333333,
#          6.66666667,  7.        ,  7.33333333,  7.66666667,  8.        ,
#          8.33333333,  8.66666667,  9.        ,  9.33333333,  9.66666667,
# ...

# %%
plt.imshow(hdu3.data)
plt.colorbar()

# %% [markdown]
# ## BINTABLE

# %%
hdu4 = data_f475w[4]
hdu4.header
# Out:
# XTENSION= 'BINTABLE'           / binary table extension
# BITPIX  =                    8 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                 2249 / length of dimension 1
# NAXIS2  =                    4 / length of dimension 2
# PCOUNT  =                    0 / number of group parameters
# GCOUNT  =                    1 / number of groups
# TFIELDS =                  311 / number of table fields
# TTYPE1  = 'ROOTNAME'
# TFORM1  = '9A      '
# TTYPE2  = 'EXTNAME '
# TFORM2  = '3A      '
# TTYPE3  = 'EXTVER  '
# TFORM3  = 'J       '
# TTYPE4  = 'A_0_2   '
# TFORM4  = 'D       '
# TTYPE5  = 'A_0_3   '
# TFORM5  = 'D       '
# TTYPE6  = 'A_0_4   '
# TFORM6  = 'D       '
# TTYPE7  = 'A_1_1   '
# TFORM7  = 'D       '
# TTYPE8  = 'A_1_2   '
# TFORM8  = 'D       '
# TTYPE9  = 'A_1_3   '
# TFORM9  = 'D       '
# TTYPE10 = 'A_2_0   '
# TFORM10 = 'D       '
# TTYPE11 = 'A_2_1   '
# TFORM11 = 'D       '
# TTYPE12 = 'A_2_2   '
# ...

# %%
dict(zip(hdu4.columns.names, hdu4.data[0]))
# Out:
# {'ACQNAME': nan,
#  'APERTURE': 'WFC',
#  'ASN_ID': 'J8FS01020',
#  'ASN_MTYP': 'EXP-CRJ',
#  'ASN_TAB': 'j8fs01020_asn.fits',
#  'ATODCORR': 'OMIT',
#  'ATODGNA': 0.99989998,
#  'ATODGNB': 0.97210002,
#  'ATODGNC': 1.0107,
#  'ATODGND': 1.018,
#  'ATODTAB': 'N/A',
#  'A_0_2': 2.17178687620328e-06,
#  'A_0_3': 8.15594987986651e-12,
#  'A_0_4': 1.34064915129449e-14,
#  'A_1_1': -5.2234970892259e-06,
#  'A_1_2': -5.2544479882345e-10,
#  'A_1_3': -4.2256196108355e-15,
#  'A_2_0': 8.54961504268637e-06,
#  'A_2_1': -3.348251913599e-11,
#  'A_2_2': 3.60561214557004e-14,
#  'A_3_0': -4.8511341303231e-10,
#  'A_3_1': 8.25996039020535e-15,
#  'A_4_0': 2.38574467191857e-14,
#  'A_ORDER': 5,
#  'BADINPDQ': 0,
#  'BIASCORR': 'COMPLETE',
#  'BIASFILE': 'jref$n711230jj_bia.fits',
#  'BIASLEVA': 2431.5396,
#  'BIASLEVB': 2456.8694,
#  'BIASLEVC': 2470.5161,
#  'BIASLEVD': 2516.2949,
#  'BINAXIS1': 1,
#  'BINAXIS2': 1,
#  'BITPIX': 16,
#  'BLEVCORR': 'COMPLETE',
# ...

# %%
hdu4.data['SKYSUB']
# Out:
# chararray(['', '', '', ''], dtype='<U1')

# %%
hdu4.data['SKYSUM']
# Out:
# array([0., 0., 0., 0.])

# %%
hdu4.data['MDRIZSKY']
# Out:
# array([0.        , 0.        , 0.87319314, 0.87319314])

# %%
np.array(hdu4.columns.names)[np.array(hdu4.data[0]) != np.array(hdu4.data[1])]
# Out:
# array(['EXTVER', 'A_0_2', 'A_0_3', 'A_0_4', 'A_1_1', 'A_1_2', 'A_1_3',
#        'A_2_0', 'A_2_1', 'A_2_2', 'A_3_0', 'A_3_1', 'A_4_0', 'B_0_2',
#        'B_0_3', 'B_0_4', 'B_1_1', 'B_1_2', 'B_1_3', 'B_2_0', 'B_2_1',
#        'B_2_2', 'B_3_0', 'B_3_1', 'B_4_0', 'CCDCHIP', 'CD1_1', 'CD1_2',
#        'CD2_1', 'CD2_2', 'CRVAL1', 'CRVAL2', 'GOODMAX', 'GOODMEAN',
#        'GOODMIN', 'IDCV2REF', 'IDCV3REF', 'MEANBLEV', 'MEANDARK',
#        'NGOODPIX', 'OCX10', 'OCX11', 'OCY10', 'OCY11', 'ORIENTAT',
#        'SNRMAX', 'SNRMEAN', 'SNRMIN', 'LATPOLEO', 'CD1_1O', 'CD1_2O',
#        'CD2_1O', 'CD2_2O', 'CRVAL1O', 'CRVAL2O'], dtype='<U8')

# %% [markdown]
# ## EXP

# %%
hdu5 = data_f475w[5]
hdu5.header
# Out:
# XTENSION= 'IMAGE   '           / Image extension
# BITPIX  =                  -32 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                 5611
# NAXIS2  =                 5598
# PCOUNT  =                    0 / number of parameters
# GCOUNT  =                    1 / number of groups
# EXTNAME = 'EXP     '

# %%
plt.imshow(hdu5.data)
plt.colorbar()

# %% [markdown]
# Same as Weight image!

# %% [markdown]
# # F850LP

# %%
data_f850lp[0].header
# Out:
# SIMPLE  =                    T / Fits standard
# BITPIX  =                   16 / Bits per pixel
# NAXIS   =                    0 / Number of axes
# EXTEND  =                    T / File may contain extensions
# ORIGIN  = 'NOAO-IRAF FITS Image Kernel July 2003' / FITS file originator
# DATE    = '2017-08-12         ' / Date FITS file was generated
# IRAF-TLM= '2017-08-13T02:00:16' / Time of last modification
# COMMENT   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
#
# TELESCOP= 'HST'                / telescope used to acquire data
# INSTRUME= 'ACS   '             / identifier for instrument used to acquire data
#
#               / DATA DESCRIPTION KEYWORDS
#
# IMAGETYP= 'EXT               ' / type of exposure identifier
# PRIMESI = 'ACS   '             / instrument designated as prime
#
#               / TARGET INFORMATION
#
# ...

# %%
data_f850lp[4].data['mdrizsky']
# Out:
# array([1.30322099, 1.30322099, 1.12934828, 1.12934828, 0.        ,
#        0.        ])

# %%
data_f850lp[4].data['exptime']
# Out:
# array([ 90.,  90., 560., 560., 560., 560.])

# %%
hdu4.columns
# Out:
# ColDefs(
#     name = 'ROOTNAME'; format = '9A'
#     name = 'EXTNAME'; format = '3A'
#     name = 'EXTVER'; format = 'J'
#     name = 'A_0_2'; format = 'D'
#     name = 'A_0_3'; format = 'D'
#     name = 'A_0_4'; format = 'D'
#     name = 'A_1_1'; format = 'D'
#     name = 'A_1_2'; format = 'D'
#     name = 'A_1_3'; format = 'D'
#     name = 'A_2_0'; format = 'D'
#     name = 'A_2_1'; format = 'D'
#     name = 'A_2_2'; format = 'D'
#     name = 'A_3_0'; format = 'D'
#     name = 'A_3_1'; format = 'D'
#     name = 'A_4_0'; format = 'D'
#     name = 'ACQNAME'; format = 'D'
#     name = 'A_ORDER'; format = 'J'
#     name = 'APERTURE'; format = '3A'
#     name = 'ASN_ID'; format = '9A'
#     name = 'ASN_MTYP'; format = '7A'
#     name = 'ASN_TAB'; format = '18A'
#     name = 'ATODCORR'; format = '4A'
#     name = 'ATODGNA'; format = 'D'
#     name = 'ATODGNB'; format = 'D'
#     name = 'ATODGNC'; format = 'D'
#     name = 'ATODGND'; format = 'D'
#     name = 'ATODTAB'; format = '3A'
# ...

# %% [markdown]
# # Combined

# %%
h1 = data_f475w[0].header
h2 = data_f850lp[0].header

# %%
d1 = dict(h1.items())
d2 = dict(h2.items())

# %%
for k, v1 in d1.items():
    v2 = d2[k]
    if v1 != v2:
        print(k, h1.comments[k])
        print('     ', v1, v2)
# Out:
# IRAF-TLM Time of last modification
#       2017-08-13T02:01:13 2017-08-13T02:00:16
# SUNANGLE angle between sun and V1 axis
#       96.026253 96.044769
# MOONANGL angle between moon and V1 axis
#       146.911499 146.660233
# SUN_ALT altitude of the sun above Earth's limb
#       -12.585434 93.606094
# EXPSTART exposure start time (Modified Julian Date)
#       52809.30429752 52809.28511938
# EXPEND exposure end time (Modified Julian Date)
#       52809.31456447 52809.30230743
# EXPTIME exposure duration (seconds)--calculated
#       750.0 1210.0
# TEXPTIME
#       750.0 1210.0
# DARKTIME fiducial pixel dark time (secs)
#       378.239202 93.247202
# CSYS_VER Calibration software system version id
#       hstdp-2016.1 hstdp-2016.2
# FILTER1 element selected from filter wheel 1
#       F475W F850LP
# CRSPLIT number of cosmic ray split exposures
#       2 1
# CRCORR combine observations to reject cosmic rays
#       PERFORM MULTIPLE
# CRREJTAB cosmic ray rejection parameters
# ...
