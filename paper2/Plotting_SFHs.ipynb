# %%
import numpy as np, matplotlib.pyplot as plt, matplotlib as mpl
import pcmdpy as ppy
# %matplotlib inline

# %%
r = ppy.results.ResultsPlotter('results/M31_b_m1.csv', dmod_true=24.47)

# %%
r2 = ppy.results.ResultsPlotter('results/M87_r104_m1.csv', dmod_true=31.)

# %%
r.plot_corner_sfh(cumulative=True);

# %%
r.plot_corner_sfh(cumulative=False);

# %%
r.plot_cum_sfh();

# %%
r.plot_cum_sfh(bulk_norm=False);

# %%
r2.plot_cum_sfh(width=95.);

# %%
r2.plot_cum_sfh(bulk_norm=False, width=95.);

# %%
r2.plot_cum_sfh(bulk_norm=False, width=95., max_logl=r2.df.logl.min());

# %%
a = np.random.random(size=(10000, 30))

# %%
b = np.cumsum(a, axis=1)

# %%
(b.T / b[:,-1]).T
# Out:
# array([[0.00702566, 0.03935937, 0.05551147, ..., 0.95228635, 0.95791977,
#         1.        ],
#        [0.02382094, 0.08666114, 0.10367595, ..., 0.90830001, 0.94735363,
#         1.        ],
#        [0.04002013, 0.08024477, 0.10981261, ..., 0.88565113, 0.9622477 ,
#         1.        ],
#        ...,
#        [0.00444482, 0.05374904, 0.05610048, ..., 0.96005696, 0.99111809,
#         1.        ],
#        [0.01136217, 0.06747046, 0.090286  , ..., 0.96409501, 0.97147573,
#         1.        ],
#        [0.03874068, 0.04751409, 0.05590664, ..., 0.9424132 , 0.98769203,
#         1.        ]])
